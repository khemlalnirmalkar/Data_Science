# %%
import numpy as np
import pandas as pd
#netowrk analysis
import networkx as nx
#plotting
#imports for plotly interactive visualisation library
#import plotly.graph_objs as go
#from plotly.graph_objs import *
#from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import numpy as np
import matplotlib.ticker as mtick  ## to set axes with scientific number e.g. 4.00e-6

# %%
pwd
# Out:
# 'D:\\ResearchBioDesign_ASU\\Autism-MetagenomData\\metagenomMetabolome\\correlation\\plasma_taxa_corr\\mixCorr\\jupy'

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.lmplot.html ##tips

# %%
cresol = pd.read_excel('D://ResearchBioDesign_ASU//Autism-MetagenomData//metagenomMetabolome//correlation//plasma_taxa_corr//mixCorr/jupy/corr_cresol_KN.xlsx')
df1= pd.DataFrame(cresol)

# %%
df1.head(5)
# Out:
#    ASD_Baseline  MTT_10wk        TD  ASD_Baseline_r    MTT_10wk_r  \
# 0     -0.508399 -0.151692 -1.034412    4.220000e-07  1.250000e-06
# 1     -0.055567  0.576138  0.691691    3.990000e-07  1.480000e-06
# 2     -0.049152  0.095340 -0.952784    3.730000e-07  2.090000e-06
# 3      3.104945  0.571191 -0.220666    2.070000e-06  1.790000e-07
# 4      0.807977  0.783862 -1.003543    1.640000e-06  2.200000e-06
#
#            TD_r  ASD_Baseline_e  ASD_Baseline_p  MTT_10wk_p      TD_p  ...  \
# 0  1.000000e-06    0.000000e+00    3.520000e-06    0.000003  0.000003  ...
# 1  2.430000e-06    6.650000e-08    7.320000e-07    0.000002  0.000010  ...
# 2  1.410000e-06    0.000000e+00    1.320000e-06    0.000008  0.000011  ...
# 3  4.910000e-07    1.540000e-06    6.830000e-06    0.000003  0.000004  ...
# 4  2.170000e-06    1.370000e-07    4.780000e-06    0.000004  0.000006  ...
#
#    ID_total   fullGroup  \
# 0     MS117  MajorDonor
# 1     MS118  MajorDonor
# 2     MS119  MajorDonor
# ...

# %%
 textstr = 'fill_test'
    #Major_Donor_Values=df2[df2["Group"]=='MajorDonor']
    #Minor_Donor_Values=df2[df2["Group"]=='MaintenanceDonor']
Baseline_values=df1[df1["Group"]=='Baseline']
Neurotypical_values=df1[df1["Group"]=='TD']  ### old one was Neurotypical
MTT_10=df1[df1["Group"]=='MTT_10wk']
MTT_2yr=df1[df1["Group"]=='MTT_2yr']

# %%
g = sns.lmplot(x="Selenomonas_species", y="SULFUR_KO1082", hue="Group", data=df1)

# %%
g = sns.lmplot(x="SelenoALL", y="SULFUR_KO1082", hue="Group", data=df1, col="Group") ##separate the graph

# %%
g = sns.lmplot(x="SelenoALL", y="SULFUR_KO1082", hue="Group", data=df1, col="Group", col_wrap=2, height=3)

# %%
sns.lmplot(x="Desulfovibrio_species", y="SULFUR_KO1082", col="Group", data=df1)

# %%
g = sns.jointplot(y='SULFUR_KO1082', x='Desulfovibrio_species', data=df1 ,kind='reg', scatter = False)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.jointplot(y='Desulfovibrio_species', x='SULFUR_KO1082', data=df1, kind='reg', joint_kws={'color':'violet'},scatter = False)

g.ax_marg_x.remove()
g.ax_marg_y.remove()
sns.scatterplot(y='Desulfovibrio_species', x='SULFUR_KO1082', data=df1, hue="Group", ax=g.ax_joint)

plt.show()
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SelenomonasBaseline, df1.Sulfur1082_KO_baseline, ax=ax, label='ASD_Baseline', color="r")
ax.set(ylabel='Selenomonas.', xlabel='Sulfur_KO')
ax.set_xlabel('Sulfur_KO',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Selenomonas sps.',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=0.60  P-value=0.01', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('SulfurKO1082_Seleno_single_corr.svg', bbox_inches='tight')
fig1.savefig('SulfurKO1082_Seleno_single_corr.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df1.head(5)
# Out:
#    ASD_Baseline  MTT_10wk        TD  ASD_Baseline_r    MTT_10wk_r  \
# 0     -0.508399 -0.151692 -1.034412    4.220000e-07  1.250000e-06
# 1     -0.055567  0.576138  0.691691    3.990000e-07  1.480000e-06
# 2     -0.049152  0.095340 -0.952784    3.730000e-07  2.090000e-06
# 3      3.104945  0.571191 -0.220666    2.070000e-06  1.790000e-07
# 4      0.807977  0.783862 -1.003543    1.640000e-06  2.200000e-06
#
#            TD_r  ASD_Baseline_e  ASD_Baseline_p  MTT_10wk_p      TD_p  ...  \
# 0  1.000000e-06    0.000000e+00    3.520000e-06    0.000003  0.000003  ...
# 1  2.430000e-06    6.650000e-08    7.320000e-07    0.000002  0.000010  ...
# 2  1.410000e-06    0.000000e+00    1.320000e-06    0.000008  0.000011  ...
# 3  4.910000e-07    1.540000e-06    6.830000e-06    0.000003  0.000004  ...
# 4  2.170000e-06    1.370000e-07    4.780000e-06    0.000004  0.000006  ...
#
#    Selenomonas10wk  SelenoTD  SelenomonasBaseline   shrtGrp  SULFUR_KO1082  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.Selenomonas_species, df1.SULFUR_KO1082, ax=ax, color="r", label='Spearman r=-0.530, p<0.0001')
sns.regplot(df1.Selenomonas_species, df1.SULFUR_KO1082, ax=ax, color="r", label='Pearson r=-0.534, p<0.0001')
ax.set(ylabel='Selenomonas_species', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=18)
ax.set_ylabel('Relative abudnance (%) Selenomonas sps.',fontsize=18)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)

##change the font size of x (abundance) n y (group name) axis ticks
plt.yticks(fontsize=13)
plt.xticks(fontsize=13) #fontweight='semibold'
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
#fig1.savefig('SulfurKO1082_Seleno_mix_corrPval.svg', bbox_inches='tight')
#fig1.savefig('SulfurKO1082_Seleno_mix_corrPval.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ***alternate way of adjusting font size of legend***

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.Selenomonas_species, df1.SULFUR_KO1082, ax=ax, color="r")
sns.regplot(df1.Selenomonas_species, df1.SULFUR_KO1082, ax=ax, color="r")
ax.set(ylabel='Selenomonas_species', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=18)
ax.set_ylabel('Selenomonas sps.',fontsize=18)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)

##change the font size of x (abundance) n y (group name) axis ticks
plt.yticks(fontsize=13)
plt.xticks(fontsize=13) #fontweight='semibold'
plt.legend(labels=["Spearman r=-0.530, p<0.0001","Pearson r=-0.534, p<0.0001"], fontsize = 18)
plt.tick_params(axis='both', which='major', labelsize=18)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('SulfurKO1082_Seleno_mix_corrPvalV02.svg', bbox_inches='tight')
fig1.savefig('SulfurKO1082_Seleno_mix_corrPvalV02.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
#for Desulfovibrio piger
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_piger, ax=ax, color="r")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_piger, ax=ax, color="r")
ax.set(ylabel='Desulfovibrio_piger', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=18)
ax.set_ylabel('Desulfovibrio_piger',fontsize=18)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
plt.yticks(fontsize=13)
plt.xticks(fontsize=13) #fontweight='semibold'
plt.legend(labels=["Spearman r=-0.50, p<0.0001","Pearson r=-0.29, p=0.01"], fontsize = 18)
plt.tick_params(axis='both', which='major', labelsize=18)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('Desulfovibrio_pigerAllvsK01082PvalV02.svg', bbox_inches='tight')
fig1.savefig('Desulfovibrio_pigerAllvsK01082PvalV02.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
****************************************** END of all sample correlations

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
#colors = ['#78C850', '#F08030', '#6890F0']
#fig = plt.figure(figsize=(7, 6), facecolor='white') ##edgecolor='red'
#sns.regplot(data=df1, x='Group', y=Sulfur_KO, hue='Group',
                   #size=12, palette=colors, facecolor='none')
sns.regplot(df1.SelenoALL, df1.SULFUR_KO1082, ax=ax, color="r")
#ax.set(ylabel='Selenomonas.', xlabel='Sulfur_KO')
ax.set_xlabel('SULFUR_KO1082',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Selenomonas sps.',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
#plt.show()
#plt.savefig('SulfurKO1082_Seleno_mix_corr.svg')
fig1.savefig('SulfurKO1082_Seleno_mix_corr.svg', bbox_inches='tight')
fig1.savefig('SulfurKO1082_Seleno_mix_corr.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_species, ax=ax, color="r") #label='ASD_Baseline',
ax.set(ylabel='Desulfovibrio_species', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Desulfovibrio species',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('Desulfovibrio_SpsAllvsK01082.svg', bbox_inches='tight')
fig1.savefig('Desulfovibrio_SpsAllvsK01082.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
# ASD014 was removed, because of higher abundance"0.02" 
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_species_edt, ax=ax, color="r") #label='ASD_Baseline',
ax.set(ylabel='Desulfovibrio_species_edt', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Desulfovibrio species',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('Desulfovibrio_SpsEDTvsK01082.svg', bbox_inches='tight')
fig1.savefig('Desulfovibrio_SpsEDTvsK01082.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_piger, ax=ax, color="r"), #label='ASD_Baseline',
ax.set(ylabel='Desulfovibrio_piger', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Desulfovibrio_piger',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('Desulfovibrio_pigerAllvsK01082.svg', bbox_inches='tight')
fig1.savefig('Desulfovibrio_pigerAllvsK01082.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_piger, ax=ax, color="r", label='Spearman r=-0.50, p<0.0001')
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_piger, ax=ax, color="r", label='Pearson r=-0.29, p=0.01')
ax.set(ylabel='Desulfovibrio_piger', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Desulfovibrio_piger',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('Desulfovibrio_pigerAllvsK01082Pval.svg', bbox_inches='tight')
fig1.savefig('Desulfovibrio_pigerAllvsK01082Pval.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
#sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.SULFUR_KO1082, df1.Desulfovibrio_piger_edt, ax=ax, color="r") #label='ASD_Baseline',
ax.set(ylabel='Desulfovibrio_piger_edt', xlabel='SULFUR_KO1082')
ax.set_xlabel('K01082 (Sulfur metabolism)',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Desulfovibrio_piger',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=-0.69  P-value=0.001', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
#plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('Desulfovibrio_pigerEDTvsK01082.svg', bbox_inches='tight')
fig1.savefig('Desulfovibrio_pigerEDTvsK01082.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.regplot(df1.Selenomonas10wk, df1.Sulfur1082_KO_10wk, ax=ax, label='MTT_10wk', color="b")
sns.regplot(df1.SelenoTD, df1.Sulfur1082_KO_TD, ax=ax, label='TD', color="g")
sns.regplot(df1.SelenomonasBaseline, df1.Sulfur1082_KO_baseline, ax=ax, label='ASD_Baseline', color="r")
ax.set(ylabel='Selenomonas.', xlabel='Sulfur_KO')
ax.set_xlabel('Sulfur_KO',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Selenomonas sps.',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=0.60  P-value=0.01', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
#fig1.savefig('pCresol_Rhodo_mix_corr.svg', bbox_inches='tight')
#fig1.savefig('pCresol_Rhodo_mix_corr.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#sns.regplot(df1.Selenomonas10wk, df1.Sulfur1082_KO_10wk, ax=ax, label='MTT_10wk', color="b")
sns.regplot(df1.SelenoTD, df1.Sulfur1082_KO_TD, ax=ax, label='TD', color="g")
sns.regplot(df1.SelenomonasBaseline, df1.Sulfur1082_KO_baseline, ax=ax, label='ASD_Baseline', color="r")
ax.set(ylabel='Selenomonas.', xlabel='Sulfur_KO')
ax.set_xlabel('Sulfur_KO',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Selenomonas sps.',fontsize=15)
#ax.text(-2.5,.000008, 'ASD_Baseline  R=0.60  P-value=0.01', color="r",fontsize=12)
#ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
#ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
plt.title('Selenomonas vs Sulfur KO.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
#fig1.savefig('pCresol_Rhodo_mix_corr.svg', bbox_inches='tight')
#fig1.savefig('pCresol_Rhodo_mix_corr.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
***************************** END Feb 2022******************

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk')
sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD')
sns.regplot(df1.ASD_Baseline, df1.ASD_Baseline_r, ax=ax, label='ASD_Baseline')
ax.set(ylabel='s.Rhodococcus', xlabel='Normalized p-Cresol-sulfate')
ax.set_xlabel('Normalized p-Cresol-sulfate',fontsize=15)
ax.set_ylabel('s.Rhodococcus Concentration',fontsize=15)
ax.text(-2,.000008, 'ASD_Baseline  R=0.60  P-value=0.01', color="r",fontsize=12)
ax.text(-2,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
ax.text(-2,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
plt.title('Normalized p-Cresol-sulfate vs s.Rhodococcus', fontsize = 20)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.ASD_Baseline, df1.ASD_Baseline_r, ax=ax, label='ASD_Baseline', color="r")
ax.set(ylabel='Rhodococcus sps.', xlabel='Normalized p-Cresol-sulfate')
ax.set_xlabel('Normalized p-Cresol-sulfate',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Rhodococcus sps.',fontsize=15)
ax.text(-2.5,.000008, 'ASD_Baseline  R=0.60  P-value=0.01', color="r",fontsize=12)
ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 13)
plt.title('Normalized p-Cresol-sulfate vs. Rhodococcus sps.', fontsize = 20)
fig1 = plt.gcf()
#plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('pCresol_Rhodo_mix_corr.svg', bbox_inches='tight')
fig1.savefig('pCresol_Rhodo_mix_corr.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.show()
plt.savefig('pCresol_Rhodo_mix_corr.svg')
#fig1.savefig(taxa_target+'.svg', bbox_inches='tight')
plt.savefig('pCresol_Rhodo_mix_corr.png', bbox_inches='tight', dpi=500)

# %%
#plt.show()
plt.savefig('pCresol_Rhodo_mix_corr.png', dpi=500)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.regplot(df1.MTT_10wk, df1.MTT_10wk_r, ax=ax, label='MTT_10wk', color="b")
sns.regplot(df1.TD, df1.TD_r, ax=ax, label='TD', color="g")
sns.regplot(df1.ASD_Baseline, df1.ASD_Baseline_r, ax=ax, label='ASD_Baseline', color="r")
#ax.axhline(xmin=-3, xmax=3)
ax.set_xlim([-2,3.2])
#for scientific notation on y axes numbers
#ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
ax.set(ylabel='Rhodococcus sps.', xlabel='Normalized p-Cresol-sulfate')
ax.set_xlabel('Normalized p-Cresol-sulfate',fontsize=15)
ax.set_ylabel('Relative abudnance (%) Rhodococcus sps.',fontsize=15)
ax.text(-2.5,.000008, 'ASD_Baseline  R=0.60  P-value=0.01', color="r",fontsize=12)
ax.text(-2.5,.000007, 'MTT_10wks  R=-0.48  P-value=0.05', color='b',fontsize=12)
ax.text(-2.5,.000006, 'TD  R=-0.18  P-value=0.43', color='g', fontsize=12)
ax.legend(fontsize = 10)
plt.title('Normalized p-Cresol-sulfate vs. Rhodococcus sps.', fontsize = 20)
fig1 = plt.gcf()
plt.show()
#plt.savefig('pCresol_Rhodo_mix_corr.svg')
fig1.savefig('pCresol_Rhodo_mix_corr.svg', bbox_inches='tight')
fig1.savefig('pCresol_Rhodo_mix_corr.png', bbox_inches='tight', dpi=500)
# Out:
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\knirmalk\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plt.show()
plt.savefig('pCresol_plancto_mix_corr.svg')

# %%
#plt.show()
plt.savefig('pCresol_Edwardsiella_mix_corr.svg')
